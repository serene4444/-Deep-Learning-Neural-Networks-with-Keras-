# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Convolutional Neural Networks with Keras
#
# Estimated time needed **30** mins

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build convolutional neural networks
# * Convolutional neural network with one set of convolutional and pooling layers
# * Convolutional neural network with two sets of convolutional and pooling layers

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a>
# 2. <a href="#Convolutional-Neural-Network-with-One-Set-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with One Set of Convolutional and Pooling Layers</a>
# 3. <a href="#Convolutional-Neural-Network-with-Two-Sets-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# ### Install the necessary libraries

# %% [markdown]
# Let's start by installing the keras libraries and the packages that we would need to build a neural network.

# %%
# All Libraries required for this lab are listed below. The libraries need to be installed on Skills Network Labs. 
# If you run this notebook on a different environment, e.g. your desktop, you may want to install these.
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# !pip install matplotlib==3.9.2
# Out:
# Collecting numpy==2.0.2
#   Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.0.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Mercu\anaconda3\Lib\site-packages\~~mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Mercu\anaconda3\Lib\site-packages\~~mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# Requirement already satisfied: pandas==2.2.2 in c:\users\mercu\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mercu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)
# Requirement already satisfied: tensorflow_cpu==2.18.0 in c:\users\mercu\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.76.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.13.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mercu\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.44.0)
# Requirement already satisfied: rich in c:\users\mercu\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (13.7.1)
# Requirement already satisfied: namex in c:\users\mercu\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\mercu\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mercu\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mercu\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mercu\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mercu\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mercu\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mercu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.0)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\mercu\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mercu\anaconda3\lib\site-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Collecting numpy>=1.23 (from matplotlib==3.9.2)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: six>=1.5 in c:\users\mercu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.16.0)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.26.4

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ## Import Keras and Packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical
# Out:
# c:\Users\Mercu\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers import Conv2D # to add convolutional layers
from keras.layers import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# ## Convolutional Neural Network with One Set of Convolutional and Pooling Layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 6s - 21ms/step - accuracy: 0.9196 - loss: 0.2865 - val_accuracy: 0.9708 - val_loss: 0.1007
# Epoch 2/10
# 300/300 - 6s - 20ms/step - accuracy: 0.9762 - loss: 0.0828 - val_accuracy: 0.9816 - val_loss: 0.0627
# Epoch 3/10
# 300/300 - 6s - 19ms/step - accuracy: 0.9833 - loss: 0.0576 - val_accuracy: 0.9846 - val_loss: 0.0475
# Epoch 4/10
# 300/300 - 5s - 18ms/step - accuracy: 0.9859 - loss: 0.0454 - val_accuracy: 0.9848 - val_loss: 0.0448
# Epoch 5/10
# 300/300 - 6s - 18ms/step - accuracy: 0.9891 - loss: 0.0359 - val_accuracy: 0.9855 - val_loss: 0.0429
# Epoch 6/10
# 300/300 - 6s - 18ms/step - accuracy: 0.9910 - loss: 0.0307 - val_accuracy: 0.9875 - val_loss: 0.0384
# Epoch 7/10
# 300/300 - 6s - 19ms/step - accuracy: 0.9917 - loss: 0.0266 - val_accuracy: 0.9859 - val_loss: 0.0449
# Epoch 8/10
# 300/300 - 6s - 19ms/step - accuracy: 0.9933 - loss: 0.0211 - val_accuracy: 0.9871 - val_loss: 0.0396
# Epoch 9/10
# 300/300 - 6s - 21ms/step - accuracy: 0.9941 - loss: 0.0189 - val_accuracy: 0.9871 - val_loss: 0.0368
# Epoch 10/10
# 300/300 - 6s - 21ms/step - accuracy: 0.9953 - loss: 0.0155 - val_accuracy: 0.9869 - val_loss: 0.0371
# Accuracy: 0.9868999719619751
#  Error: 1.3100028038024902

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ## Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 7s - 24ms/step - accuracy: 0.8664 - loss: 0.4811 - val_accuracy: 0.9615 - val_loss: 0.1258
# Epoch 2/10
# 300/300 - 6s - 21ms/step - accuracy: 0.9676 - loss: 0.1078 - val_accuracy: 0.9772 - val_loss: 0.0754
# Epoch 3/10
# 300/300 - 6s - 19ms/step - accuracy: 0.9775 - loss: 0.0750 - val_accuracy: 0.9827 - val_loss: 0.0566
# Epoch 4/10
# 300/300 - 7s - 23ms/step - accuracy: 0.9811 - loss: 0.0613 - val_accuracy: 0.9795 - val_loss: 0.0648
# Epoch 5/10
# 300/300 - 7s - 23ms/step - accuracy: 0.9840 - loss: 0.0523 - val_accuracy: 0.9857 - val_loss: 0.0432
# Epoch 6/10
# 300/300 - 7s - 23ms/step - accuracy: 0.9862 - loss: 0.0452 - val_accuracy: 0.9837 - val_loss: 0.0482
# Epoch 7/10
# 300/300 - 7s - 23ms/step - accuracy: 0.9872 - loss: 0.0403 - val_accuracy: 0.9858 - val_loss: 0.0460
# Epoch 8/10
# 300/300 - 7s - 24ms/step - accuracy: 0.9887 - loss: 0.0362 - val_accuracy: 0.9879 - val_loss: 0.0363
# Epoch 9/10
# 300/300 - 7s - 24ms/step - accuracy: 0.9898 - loss: 0.0331 - val_accuracy: 0.9900 - val_loss: 0.0320
# Epoch 10/10
# 300/300 - 7s - 23ms/step - accuracy: 0.9906 - loss: 0.0297 - val_accuracy: 0.9891 - val_loss: 0.0324
# Accuracy: 0.9890999794006348
#  Error: 1.0900020599365234

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Let's see how batch size affects the time required and accuracy of the model training.
# For this, you can try to change batch_size to 1024 and check it's effect on accuracy

# %%
# Write your answer here
#build the model 
model = convolutional_model()

#fit the model 
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

#evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
# Now, let's see how number of epochs  affect the time required and accuracy of the model training.
# For this, you can keep the batch_size=1024 and epochs=25 and check it's effect on accuracy

# %%
# Write your answer here

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
#
#
#     -->

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>

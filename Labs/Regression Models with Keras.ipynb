# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Regression Models with Keras
#
# Estimated time needed: **45** mins

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean the Data Set</a>
# 2. <a href="#item32">Import Keras Packages</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean the  Data Set

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.
# %pip install numpy==1.26.4
# %pip install pandas==2.2.2
# %pip install tensorflow_cpu==2.18.0
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\users\mercu\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas==2.2.2 in c:\users\mercu\anaconda3\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mercu\anaconda3\lib\site-packages (from pandas==2.2.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mercu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)
# Requirement already satisfied: tensorflow_cpu==2.18.0 in c:\users\mercu\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.76.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.13.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mercu\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.44.0)
# Requirement already satisfied: rich in c:\users\mercu\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (13.7.1)
# Requirement already satisfied: namex in c:\users\mercu\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.0)
# Requirement already satisfied: optree in c:\users\mercu\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mercu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mercu\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mercu\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mercu\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mercu\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mercu\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mercu\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mercu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow_cpu==2.18.0) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 48ms/step - loss: 1656.3708 - val_loss: 1155.8975
# Epoch 2/100
# 23/23 - 0s - 6ms/step - loss: 1530.3835 - val_loss: 1042.4896
# Epoch 3/100
# 23/23 - 0s - 7ms/step - loss: 1343.5417 - val_loss: 873.3775
# Epoch 4/100
# 23/23 - 0s - 5ms/step - loss: 1063.9985 - val_loss: 650.8888
# Epoch 5/100
# 23/23 - 0s - 5ms/step - loss: 725.2531 - val_loss: 420.5116
# Epoch 6/100
# 23/23 - 0s - 5ms/step - loss: 430.9820 - val_loss: 256.9566
# Epoch 7/100
# 23/23 - 0s - 5ms/step - loss: 278.8055 - val_loss: 191.0861
# Epoch 8/100
# 23/23 - 0s - 5ms/step - loss: 237.3488 - val_loss: 174.4353
# Epoch 9/100
# 23/23 - 0s - 5ms/step - loss: 220.8695 - val_loss: 168.7995
# Epoch 10/100
# 23/23 - 0s - 5ms/step - loss: 207.9771 - val_loss: 166.1185
# Epoch 11/100
# 23/23 - 0s - 5ms/step - loss: 198.7134 - val_loss: 164.1276
# Epoch 12/100
# 23/23 - 0s - 8ms/step - loss: 190.6033 - val_loss: 163.4753
# Epoch 13/100
# 23/23 - 0s - 5ms/step - loss: 184.0183 - val_loss: 161.1336
# Epoch 14/100
# 23/23 - 0s - 5ms/step - loss: 179.3728 - val_loss: 160.5130
# Epoch 15/100
# 23/23 - 0s - 5ms/step - loss: 173.7558 - val_loss: 161.7875
# Epoch 16/100
# 23/23 - 0s - 4ms/step - loss: 169.9975 - val_loss: 158.5871
# Epoch 17/100
# 23/23 - 0s - 4ms/step - loss: 166.4603 - val_loss: 160.6436
# Epoch 18/100
# 23/23 - 0s - 5ms/step - loss: 162.4430 - val_loss: 159.0805
# Epoch 19/100
# 23/23 - 0s - 6ms/step - loss: 159.6122 - val_loss: 159.0901
# Epoch 20/100
# 23/23 - 0s - 5ms/step - loss: 157.2543 - val_loss: 159.6731
# Epoch 21/100
# 23/23 - 0s - 5ms/step - loss: 154.3366 - val_loss: 157.9942
# Epoch 22/100
# 23/23 - 0s - 5ms/step - loss: 152.3414 - val_loss: 158.0572
# Epoch 23/100
# 23/23 - 0s - 4ms/step - loss: 150.2789 - val_loss: 155.9877
# Epoch 24/100
# 23/23 - 0s - 5ms/step - loss: 148.2374 - val_loss: 157.4503
# Epoch 25/100
# 23/23 - 0s - 5ms/step - loss: 146.3138 - val_loss: 159.3140
# Epoch 26/100
# 23/23 - 0s - 5ms/step - loss: 144.3989 - val_loss: 157.9222
# Epoch 27/100
# 23/23 - 0s - 5ms/step - loss: 143.1630 - val_loss: 157.8624
# Epoch 28/100
# 23/23 - 0s - 4ms/step - loss: 141.0072 - val_loss: 157.2498
# Epoch 29/100
# 23/23 - 0s - 4ms/step - loss: 139.1074 - val_loss: 158.3607
# Epoch 30/100
# 23/23 - 0s - 4ms/step - loss: 137.7097 - val_loss: 155.9247
# Epoch 31/100
# 23/23 - 0s - 4ms/step - loss: 136.7740 - val_loss: 157.2208
# Epoch 32/100
# 23/23 - 0s - 5ms/step - loss: 134.6321 - val_loss: 160.2194
# Epoch 33/100
# 23/23 - 0s - 5ms/step - loss: 133.4958 - val_loss: 155.6685
# Epoch 34/100
# 23/23 - 0s - 4ms/step - loss: 132.0098 - val_loss: 158.8697
# Epoch 35/100
# 23/23 - 0s - 5ms/step - loss: 130.9142 - val_loss: 155.8901
# Epoch 36/100
# 23/23 - 0s - 5ms/step - loss: 128.9986 - val_loss: 155.3315
# Epoch 37/100
# 23/23 - 0s - 5ms/step - loss: 127.3932 - val_loss: 153.7146
# Epoch 38/100
# 23/23 - 0s - 5ms/step - loss: 125.4366 - val_loss: 152.4804
# Epoch 39/100
# 23/23 - 0s - 5ms/step - loss: 124.0160 - val_loss: 150.0935
# Epoch 40/100
# 23/23 - 0s - 5ms/step - loss: 121.8100 - val_loss: 150.2264
# Epoch 41/100
# 23/23 - 0s - 5ms/step - loss: 119.9539 - val_loss: 147.2196
# Epoch 42/100
# 23/23 - 0s - 5ms/step - loss: 117.8970 - val_loss: 147.0467
# Epoch 43/100
# 23/23 - 0s - 4ms/step - loss: 116.1064 - val_loss: 141.2112
# Epoch 44/100
# 23/23 - 0s - 5ms/step - loss: 113.7781 - val_loss: 142.9596
# Epoch 45/100
# 23/23 - 0s - 5ms/step - loss: 112.4240 - val_loss: 138.8362
# Epoch 46/100
# 23/23 - 0s - 5ms/step - loss: 110.3384 - val_loss: 137.2359
# Epoch 47/100
# 23/23 - 0s - 5ms/step - loss: 107.7670 - val_loss: 133.2301
# Epoch 48/100
# 23/23 - 0s - 5ms/step - loss: 105.6366 - val_loss: 133.0536
# Epoch 49/100
# 23/23 - 0s - 5ms/step - loss: 104.2707 - val_loss: 128.6400
# Epoch 50/100
# 23/23 - 0s - 5ms/step - loss: 101.8566 - val_loss: 123.9404
# Epoch 51/100
# 23/23 - 0s - 5ms/step - loss: 99.0147 - val_loss: 126.0714
# Epoch 52/100
# 23/23 - 0s - 5ms/step - loss: 97.0167 - val_loss: 118.0859
# Epoch 53/100
# 23/23 - 0s - 5ms/step - loss: 93.1411 - val_loss: 118.5628
# Epoch 54/100
# 23/23 - 0s - 5ms/step - loss: 90.5932 - val_loss: 113.5129
# Epoch 55/100
# 23/23 - 0s - 5ms/step - loss: 88.0372 - val_loss: 111.3693
# Epoch 56/100
# 23/23 - 0s - 5ms/step - loss: 85.4201 - val_loss: 113.6471
# Epoch 57/100
# 23/23 - 0s - 5ms/step - loss: 83.1411 - val_loss: 107.6475
# Epoch 58/100
# 23/23 - 0s - 5ms/step - loss: 80.4863 - val_loss: 103.7407
# Epoch 59/100
# 23/23 - 0s - 6ms/step - loss: 77.7343 - val_loss: 103.8786
# Epoch 60/100
# 23/23 - 0s - 5ms/step - loss: 74.7971 - val_loss: 98.9425
# Epoch 61/100
# 23/23 - 0s - 5ms/step - loss: 72.1954 - val_loss: 95.8201
# Epoch 62/100
# 23/23 - 0s - 5ms/step - loss: 69.4039 - val_loss: 95.2262
# Epoch 63/100
# 23/23 - 0s - 6ms/step - loss: 67.4055 - val_loss: 92.7336
# Epoch 64/100
# 23/23 - 0s - 5ms/step - loss: 64.8864 - val_loss: 90.2019
# Epoch 65/100
# 23/23 - 0s - 5ms/step - loss: 62.8493 - val_loss: 88.3395
# Epoch 66/100
# 23/23 - 0s - 5ms/step - loss: 60.4318 - val_loss: 91.0237
# Epoch 67/100
# 23/23 - 0s - 5ms/step - loss: 59.3953 - val_loss: 87.8930
# Epoch 68/100
# 23/23 - 0s - 5ms/step - loss: 57.2818 - val_loss: 83.7824
# Epoch 69/100
# 23/23 - 0s - 5ms/step - loss: 55.0456 - val_loss: 84.1452
# Epoch 70/100
# 23/23 - 0s - 5ms/step - loss: 53.5343 - val_loss: 81.6198
# Epoch 71/100
# 23/23 - 0s - 7ms/step - loss: 52.3920 - val_loss: 80.4946
# Epoch 72/100
# 23/23 - 0s - 5ms/step - loss: 51.3411 - val_loss: 84.7908
# Epoch 73/100
# 23/23 - 0s - 5ms/step - loss: 49.9710 - val_loss: 92.8202
# Epoch 74/100
# 23/23 - 0s - 5ms/step - loss: 49.6153 - val_loss: 85.0045
# Epoch 75/100
# 23/23 - 0s - 5ms/step - loss: 48.0996 - val_loss: 85.8881
# Epoch 76/100
# 23/23 - 0s - 6ms/step - loss: 46.8012 - val_loss: 88.5066
# Epoch 77/100
# 23/23 - 0s - 6ms/step - loss: 46.0514 - val_loss: 86.3133
# Epoch 78/100
# 23/23 - 0s - 5ms/step - loss: 44.2908 - val_loss: 89.6238
# Epoch 79/100
# 23/23 - 0s - 5ms/step - loss: 43.7232 - val_loss: 89.0069
# Epoch 80/100
# 23/23 - 0s - 5ms/step - loss: 42.5619 - val_loss: 86.9200
# Epoch 81/100
# 23/23 - 0s - 5ms/step - loss: 41.5989 - val_loss: 89.2718
# Epoch 82/100
# 23/23 - 0s - 5ms/step - loss: 40.8260 - val_loss: 95.2050
# Epoch 83/100
# 23/23 - 0s - 6ms/step - loss: 40.7606 - val_loss: 91.1513
# Epoch 84/100
# 23/23 - 0s - 5ms/step - loss: 39.6418 - val_loss: 94.5965
# Epoch 85/100
# 23/23 - 0s - 5ms/step - loss: 39.4170 - val_loss: 95.1975
# Epoch 86/100
# 23/23 - 0s - 5ms/step - loss: 38.2195 - val_loss: 93.5839
# Epoch 87/100
# 23/23 - 0s - 6ms/step - loss: 37.8061 - val_loss: 96.5916
# Epoch 88/100
# 23/23 - 0s - 4ms/step - loss: 37.5612 - val_loss: 104.8578
# Epoch 89/100
# 23/23 - 0s - 5ms/step - loss: 36.6558 - val_loss: 101.2740
# Epoch 90/100
# 23/23 - 0s - 5ms/step - loss: 36.2769 - val_loss: 96.5647
# Epoch 91/100
# 23/23 - 0s - 5ms/step - loss: 35.5572 - val_loss: 97.4006
# Epoch 92/100
# 23/23 - 0s - 5ms/step - loss: 35.9859 - val_loss: 93.6212
# Epoch 93/100
# 23/23 - 0s - 5ms/step - loss: 35.3624 - val_loss: 101.3639
# Epoch 94/100
# 23/23 - 0s - 5ms/step - loss: 34.5172 - val_loss: 107.2661
# Epoch 95/100
# 23/23 - 0s - 6ms/step - loss: 34.5201 - val_loss: 107.1368
# Epoch 96/100
# 23/23 - 0s - 7ms/step - loss: 33.4378 - val_loss: 101.3984
# Epoch 97/100
# 23/23 - 0s - 7ms/step - loss: 33.5873 - val_loss: 109.2960
# Epoch 98/100
# 23/23 - 0s - 5ms/step - loss: 32.6447 - val_loss: 119.8455
# Epoch 99/100
# 23/23 - 0s - 5ms/step - loss: 32.8972 - val_loss: 102.7213
# Epoch 100/100
# 23/23 - 0s - 5ms/step - loss: 32.3663 - val_loss: 109.3683

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# <hr>
#
# Copyright &copy; [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://opensource.org/license/mit).
